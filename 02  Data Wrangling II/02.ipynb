# %%
'''Assignment No. 2
Title of the Assignment: Data Wrangling, II
Create an “Academic performance” dataset of students and perform the following
operations using Python.
1. Scan all variables for missing values and inconsistencies. If there are missing values
and/or inconsistencies, use any of the suitable techniques to deal with them.
2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable
techniques to deal with them.
3. Apply data transformations on at least one of the variables. The purpose of this
transformation should be one of the following reasons: to change the scale for
better understanding of the variable, to convert a non-linear relation into a linear
one, or to decrease the skewness and convert the distribution into a normal
distribution. Reason and document your approach properly.'''

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student.csv")

# %%
# Finding Null Values in specific column and filling null values with "No marks".
print(pd.isnull(data['Marks']))
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# Name: Marks, dtype: bool

# %%
new_data = data['Marks'].dropna()
print(new_data)

#new_d = data.replace(to_replace='NaN',value = 'hi')
#print(new_d)

data['Marks'].fillna('No Marks',inplace=True)
print(data)
# Out:
# 0     9.88
# 1     9.77
# 4     9.02
# 5     8.89
# 7     9.89
# 8     5.00
# 13    9.88
# 14    8.83
# 15    8.88
# 16    8.99
# 17    8.88
# 18    8.88
# Name: Marks, dtype: float64
#     ID         Name  Gender Class  Marks
# 0    1        Luffy    Male    TE   9.88
# 1    2       Naruto    Male    TE   9.77
# 2    3         Nami  Female    TE    NaN
# 3    4         Zoro    Male    TE    NaN
# 4    5       Hinata  Female    TE   9.02
# 5    6       Sanket    Male    TE   8.89
# 6    7        sanji    Male    TE    NaN
# 7    8        Anish    Male    TE   9.89
# 8    9  Boa Hanckok  Female    TE   5.00
# 9   10      Tsunade  Female    TE    NaN
# 10  11       Sakura  Female    TE    NaN
# 11  12        Robin  Female    TE    NaN
# 12  13         Usap    Male    TE    NaN
# 13  14      Tanjoro    Male    TE   9.88
# 14  15       Nezuko  Female    TE   8.83
# 15  16      Zenitsu    Male    TE   8.88
# 16  17    Chainsaw`    Male    TE   8.99
# 17  18       Makimi  Female    TE   8.88
# 18  19      Rengoku    Male    TE   8.88
# 19  20          ACE    Male    TE    NaN
# 20  21         Sabo    Male    TE    NaN
# 21  22      Minato     Male    TE    NaN
# 22  23       Itachi    Male    TE    NaN
#     ID         Name  Gender Class     Marks
# 0    1        Luffy    Male    TE      9.88
# 1    2       Naruto    Male    TE      9.77
# 2    3         Nami  Female    TE  No Marks
# 3    4         Zoro    Male    TE  No Marks
# 4    5       Hinata  Female    TE      9.02
# 5    6       Sanket    Male    TE      8.89
# 6    7        sanji    Male    TE  No Marks
# 7    8        Anish    Male    TE      9.89
# 8    9  Boa Hanckok  Female    TE       5.0
# 9   10      Tsunade  Female    TE  No Marks
# 10  11       Sakura  Female    TE  No Marks
# 11  12        Robin  Female    TE  No Marks
# 12  13         Usap    Male    TE  No Marks
# 13  14      Tanjoro    Male    TE      9.88
# 14  15       Nezuko  Female    TE      8.83
# 15  16      Zenitsu    Male    TE      8.88
# 16  17    Chainsaw`    Male    TE      8.99
# 17  18       Makimi  Female    TE      8.88
# 18  19      Rengoku    Male    TE      8.88
# 19  20          ACE    Male    TE  No Marks
# 20  21         Sabo    Male    TE  No Marks
# 21  22      Minato     Male    TE  No Marks
# 22  23       Itachi    Male    TE  No Marks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("student.csv")


# Create a boxplot for the "Test 1 score" variable
boxplot = data.boxplot(column=['ID','Marks'])
plt.show()

# %%
#Detecting outliers using Scatterplot
fig, ax = plt.subplots(figsize=(18, 10))
ax.scatter(data['ID'], data['Marks'])
plt.show()

# %%
print(np.where((data['Marks']<6) & (data['Marks']>1)))
# Out:
# (array([8], dtype=int64),)

# %%
#median finding
sorted_rscore= sorted(data['Marks'])
median=np.median(sorted_rscore)
print(median)
# Out:
# nan

# %%
#Detecting outliers using Z-Score for the Math_score variable and remove the outliers. Histograph
data['Marks'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
